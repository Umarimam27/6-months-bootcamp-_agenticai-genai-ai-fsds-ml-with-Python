# %% [markdown]
# # EDA(Explaratory Data Analysis)

# %% [markdown]
# #Raw Data-- Clean Data-- ml model-- Predict-- Deploy Model-- Mlops-- cicd

# %% [markdown]
# EDA Techniques are divided into 7 parts-
#
# 1.variable Identification
# 2.Univariate Analysis
# 3.bivariate Analysis
# 4.Outlier Treatment
# 5.Missing Value Treatment
# 6.Imputation or Transformer
# 7.Variable Creation

# %% [markdown]
# 1.Variable Identification-
# Family(loan,kids,education,houseProperty)
# ->Father(govtempy)-dependent variable-target Variable-predicted variable-y
# ->Mother(home)-Independent Variable-non target Variable-non Predicted Attribute(x1)
# ->Son(2nd)-Independent Variable-non target Variable-non Predicted Attribute(x2)
# ->Daughter(5th)-Independent Variable-non target Variable-non Predicted Attribute(x3)
# y=x1+x2+x3

# %% [markdown]
# #Variable Indentification Devided into 2 Parts
# 1.Independent Variable-->x1,x2,x3
# 2.Dependent Variable-->y

# %% [markdown]
# #Machine Learning Divided into 3 Parts
# 1.Regression
# 2.Classification
# 3.Clustering

# %% [markdown]
# #Regression-Dependent Variable are Continuous
# 1.gold price
# 2.petrol price
# 3.flight fare price
# 4.electric bill price
# 5.house price
# 6.land price
# 7.stock price
# 8.crypto
# 9.food price
# 10.salary employee
#
# to build these projects we will apply regression algorithm->
# 1-simple linear regression
# 2-multiple linear regression
# 3-polynomial regression
# 4-gradient descend,stocastic gradient descend,batch gradient descend
# 5-k nearest neighbour
# 6-support vector regressor
# 7- Decision Tree Regressor
# 8-xgboost regressor
# 9.light gradient boosting regressor
# 10-ann regressor
# 11-time series

# %% [markdown]
# #Classifications-dependent variable is binary or category
# pass ~ fail pass-1 & 0
# profit or loss
# yes or no
# cat or dog
# spam or not spam
# defaulter or non defaulter
# +ve review or -ve review

# %% [markdown]
# #Classification Algorithm
# 1.logistic regression
# 2.support vector machine
# 3.knn classifier
# 4.naive bayes(bayesian theorem)
# 5.decision tree
# 6.random forest
# 7.xgboost
# 8.lgbm
# 9.ann classifier

# %% [markdown]
# #Clustreing(grouping)
#
# 1.Pca(Principal component analysis)
# 2.k-mean
# 3.hierarchical
# 4.dbscan
