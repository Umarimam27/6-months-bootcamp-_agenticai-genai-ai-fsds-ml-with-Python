# %% [markdown]
# # BitWise Operator Continue

# %%
# X-OR Operator
12^13
# Out:
# 1

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
25^30
# Out:
# 7

# %%
bin(7)
# Out:
# '0b111'

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
0b00111
# Out:
# 7

# %%
bin(10)
# Out:
# '0b1010'

# %%
10<<1
# Out:
# 20

# %%
10<<2
# Out:
# 40

# %%
10>>1
# Out:
# 5

# %%
10>>2
# Out:
# 2

# %%
10>>3
# Out:
# 1

# %% [markdown]
# #Python Operator Completed

# %%
#x=sqrt(25)

# %%
import math

# %%
x=math.sqrt(25)
x
# Out:
# 5.0

# %%
x1=math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
print(math.floor(3.87)) # Floor Function
# Out:
# 3

# %%
print(math.ceil(3.87)) # Ceil Function
# Out:
# 4

# %%
print(math.pow(3,2))
# Out:
# 9.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
# m.sqrt(25)

# %%
import math as m
m.sqrt(10)
# Out:
# 3.1622776601683795

# %%
x=input()
x
# Out:
# ''

# %%
y=input()
y
# Out:
# '10+20-30*2'

# %%
x1=input("Enter the first number")
y1=input("Enter the second number")
z1=x1+y1
print(z1)
# Out:
# 54

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %%
x1=input('user name : ') # input function
y1=input('password : ') # input function
z1=x1+y1
print(z1)
# Out:
# nareshit123456

# %%
x1=input('Enter the first number : ')
a1=int(x1)
y1=input('Enter the second number : ')
b1=int(y1)
z1=a1+b1
print(z1)
# Out:
# 90

# %%
x2=int(input('Enter the first number : '))
y2=int(input('Enter the second number : '))
z2=x2+y2
z2
# Out:
# 176

# %%
st=input('Enter the string : ')
print(st)
# Out:
# umar

# %%
print(st[0])
# Out:
# u

# %%
print(st[0:2])
# Out:
# um

# %%
st=input('enter a string')[5:7]
print(st)
# Out:
# hi

# %%
#result=input('enter an expr')
#print(result)

# %% [markdown]
# #EVAL function using input

# %%
result=eval(input('enter an expr'))
print(result)
# Out:
# 24

# %% [markdown]
# # Basic Python Completed *********************************************
