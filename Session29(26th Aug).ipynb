# %% [markdown]
# # Variable Identification

# %% [markdown]
# IV==x1,x2,x3
# DV==Y
# Relevant attributes
# Irrelevant attribute
# every time being data science we need to look for relevant attribute
# if you build the ml model with irrelevant attribute then overfitting|multicollinarity
# 1st technique we are understood well
# 1. Variable Identification
# 2. Univariate analysis(plot the )
# 3. Bivariate alaysis(plot the graph using )
# CORELATION-Relation amog attributes in the dataset
# range of correlation is -1 to 1
# +ve corre- (0 to1)
# -ve Corre-(-1 to 0)
# 0 COrre-neither +ve or -ve
# 4. Missing Value treatment--> dataset build with numerical data & categorical data
# if numerical data is missing  then we need to implement
#     mean Strategy
#     median strategy
#     mode strategy
# if categorical data is missing then we need to implement
#     MODE strategy
#     KNN  Strategy(k nearest neighbour)
# 5. OUTLIER TREATMENT
#         by plot  Graph
# 6. ImPutation or Transformer
# Transformer- Transform categorical data into numerical data to build ml models
# Trasformer also called as IMPUTATION TECHNIQUE
# NLP-- this technique we called EMBEDDING
# transformer are of 3 types-->
# 1.Dummy Variable-in this one is 1 and rest of them is 0(isme 4 attribute hain for example)
# 2.Label Encoder- isme ek 0 hoga dusra 1,teesra 2....... isme ek baar me dusra koi 0 or 1 nhi hoga
# 3.One Hot Encoder- in this one is 1 and rest of them is 0(Dummy variable me se ek attribute hata do One hot Encoder ban jayega)
# 7. Variable Creation-> from 1 varibale we will create more attributes
# EDA technical concept was completed
# EDA also called as FEATURE ENGINEERING TECHNIQUES
# Mean Strategy impact by Outlier
