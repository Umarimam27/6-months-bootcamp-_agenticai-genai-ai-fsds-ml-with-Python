# %% [markdown]
# # Python TypeCasting

# %% [markdown]
# # Int

# %%
int(2.3)

# %%
int(2.3,3.4)

# %%
int(True)

# %%
int(False)

# %%
int(1+2j)

# %%
int('10')

# %%
int('ten')

# %% [markdown]
# # Float

# %%
float(10)

# %%
float(10,20)

# %%
float(True)

# %%
float(False)

# %%
float(1+2j)

# %%
float('10')

# %%
float('ten')

# %% [markdown]
# # Complex

# %%
complex(10)

# %%
complex(10,20)

# %%
complex(10,20,30)

# %%
complex(2.3)

# %%
complex(2.3,3.4)

# %%
complex(10,'10')

# %%
complex('10',10)

# %%
complex('10')

# %% [markdown]
# # Boolean

# %%
complex(True,False)

# %%
complex(False,False)

# %%
bool(1)

# %%
bool(13)

# %%
bool()

# %%
bool( )

# %%
bool(1.2)

# %%
bool('10')

# %%
bool('ten')

# %%
bool(1+2j)

# %%
bool(0+0j)

# %% [markdown]
# # String

# %%
print(str(1))
print(str(1.2))
print(True)
print(str(1+2j))

# %% [markdown]
# # TypeCasting Completed Here
