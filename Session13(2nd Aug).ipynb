# %% [markdown]
# # Data Structures Functions

# %% [markdown]
# # List in Python Continues

# %%
l=[]
l
# Out:
# []

# %%
l.append('nit')
l.append(2.3)
l.append(1+2j)
l.append(True)
l.append([1,2,3])

# %%
l
# Out:
# ['nit', 2.3, (1+2j), True, [1, 2, 3]]

# %%
l.append(10)
l
# Out:
# ['nit', 2.3, (1+2j), True, [1, 2, 3], 10]

# %%
print(l)
# Out:
# ['nit', 2.3, (1+2j), True, [1, 2, 3], 10]

# %%
l1=[]
l1
# Out:
# []

# %%
l1=[10,2.3,1+2j,True,'hello',[1,2,3]]
l1
# Out:
# [10, 2.3, (1+2j), True, 'hello', [1, 2, 3]]

# %%
l1.append(10)
l1
# Out:
# [10, 2.3, (1+2j), True, 'hello', [1, 2, 3], 10, 10]

# %%
l1.count(10)
# Out:
# 3

# %%
l1.count(2.3)
# Out:
# 1

# %%
l1
# Out:
# [10, 2.3, (1+2j), True, 'hello', [1, 2, 3], 10, 10]

# %%
l1.remove(1+2j)

# %%
l1
# Out:
# [10, 2.3, True, 'hello', [1, 2, 3], 10, 10]

# %%
l1.pop()
# Out:
# 10

# %%
l1
# Out:
# [10, 2.3, True, 'hello', [1, 2, 3], 10]

# %%
l1.pop()
# Out:
# 10

# %%
l1
# Out:
# [10, 2.3, True, 'hello', [1, 2, 3]]

# %%
l1.pop()
# Out:
# [1, 2, 3]

# %%
l1
# Out:
# [10, 2.3, True, 'hello']

# %%
l1.remove(True)

# %%
l1
# Out:
# [10, 2.3, 'hello']

# %%
l
# Out:
# ['nit', 2.3, (1+2j), True, [1, 2, 3], 10]

# %%
l.pop(2)
# Out:
# (1+2j)

# %%
l
# Out:
# ['nit', 2.3, True, [1, 2, 3], 10]

# %%
l1
# Out:
# [10, 2.3]

# %%
l
# Out:
# ['nit', 2.3, True, [1, 2, 3], 10]

# %%
l.index('nit')
# Out:
# 0

# %%
l.index(2.3)
# Out:
# 1

# %%
l
# Out:
# ['nit', 2.3, True, [1, 2, 3], 10]

# %%
l.insert(5,4)
l
# Out:
# ['nit', 2.3, True, [1, 2, 3], 10, 4]

# %%
l
# Out:
# ['nit', 2.3, True, [1, 2, 3], 10, 4]

# %%
l.insert(4,5)

# %%
l
# Out:
# ['nit', 2.3, True, [1, 2, 3], 5, 10, 4]

# %%
l.insert(6,6)

# %%
l
# Out:
# ['nit', 2.3, True, [1, 2, 3], 5, 10, 6, 4]

# %%
print(l1)
print(l)
# Out:
# [10, 2.3]
# ['nit', 2.3, True, [1, 2, 3], 5, 10, 6, 4]

# %%
l1.extend(l)

# %%
l1
# Out:
# [10, 2.3, 'nit', 2.3, True, [1, 2, 3], 5, 10, 6, 4]

# %%
l
# Out:
# ['nit', 2.3, True, [1, 2, 3], 5, 10, 6, 4]

# %%
l.reverse()

# %%
l
# Out:
# [4, 6, 10, 5, [1, 2, 3], True, 2.3, 'nit']

# %%
l5=[300,3,34,9,100]
l5
# Out:
# [300, 3, 34, 9, 100]

# %%
l5.sort() # Ascending order

# %%
l5
# Out:
# [3, 9, 34, 100, 300]

# %%
l5.sort(reverse=True) # Descending order

# %%
l5
# Out:
# [300, 100, 34, 9, 3]

# %%
l
# Out:
# [4, 6, 10, 5, [1, 2, 3], True, 2.3, 'nit']

# %%
l5
# Out:
# [300, 100, 34, 9, 3]

# %%
l5[0]=3000

# %%
l5 #Mutable Concept
# Out:
# [3000, 100, 34, 9, 3]

# %% [markdown]
# # List in Python Completed
