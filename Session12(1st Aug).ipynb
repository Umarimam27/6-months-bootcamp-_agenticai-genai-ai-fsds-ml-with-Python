# %% [markdown]
# # Python Data Structures

# %% [markdown]
# # List

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
id(l)
# Out:
# 1305218644544

# %%
l.append
# Out:
# <function list.append(object, /)>

# %%
# l.append()

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l==l1
# Out:
# True

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l1.append(100)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 100]

# %%
l==l1
# Out:
# False

# %%
l!=l1
# Out:
# True

# %%
print(len(l))
print(len(l1))
# Out:
# 5
# 6

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50, 100]

# %%
id(l1)
# Out:
# 1305225006400

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
id(l1)
# Out:
# 1305225006400

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
#l.append(2.3,34)

# %%
l.append('nit')
l.append(2.3)
l.append(1+2j)
l.append(True)
l.append([1,2,3])

# %%
l
# Out:
# [10, 20, 30, 40, 50, 'nit', 2.3, (1+2j), 'nit', 2.3, (1+2j), True, [1, 2, 3]]

# %%
l.append(10)
l
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  'nit',
#  2.3,
#  (1+2j),
#  'nit',
#  2.3,
#  (1+2j),
#  True,
#  [1, 2, 3],
#  10,
#  10]
