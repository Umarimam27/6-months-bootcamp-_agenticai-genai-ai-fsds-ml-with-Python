# %% [markdown]
# # Statitics-II

# %% [markdown]
# #Measures of Variability
# 1.Varience
# 2.Standard deviation
# 3.coefficient of variation
#
# 1.Varience--->spread of the data towards mean is called Variance.
#     U(meu)-refers to population mean
#     a.Population variance-(sigma)2
#     b.sample variance-(s)2
# Population Standard Devation
#
# coefficient of variation=sd/mean
#
#
# eda--corelation(+ve Core,-ve,no corelate)
# statistic(corelation we called as--covarience)

# %% [markdown]
# # Descriptive Statistics

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Income_df=pd.read_csv(r"C:\Users\umari\OneDrive\Desktop\FSDS DATASETs\Inc_Exp_Data.csv")

# %%
Income_df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
Income_df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
Income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
Income_df.shape
# Out:
# (50, 7)

# %%
Income_df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
Income_df.describe().T # Transpose
# Out:
#                        count       mean            std      min       25%  \
# Mthly_HH_Income         50.0   41558.00   26097.908979   5000.0   23550.0
# Mthly_HH_Expense        50.0   18818.00   12090.216824   2000.0   10000.0
# No_of_Fly_Members       50.0       4.06       1.517382      1.0       3.0
# Emi_or_Rent_Amt         50.0    3060.00    6241.434948      0.0       0.0
# Annual_HH_Income        50.0  490019.04  320135.792123  64200.0  258750.0
# No_of_Earning_Members   50.0       1.46       0.734291      1.0       1.0
#
#                             50%       75%        max
# Mthly_HH_Income         35000.0   50375.0   100000.0
# Mthly_HH_Expense        15500.0   25000.0    50000.0
# No_of_Fly_Members           4.0       5.0        7.0
# Emi_or_Rent_Amt             0.0    3500.0    35000.0
# Annual_HH_Income       447420.0  594720.0  1404000.0
# No_of_Earning_Members       1.0       2.0        4.0

# %%
Income_df.isnull().any() # To check if there is any null value in the dataset
# Out:
# Mthly_HH_Income             False
# Mthly_HH_Expense            False
# No_of_Fly_Members           False
# Emi_or_Rent_Amt             False
# Annual_HH_Income            False
# Highest_Qualified_Member    False
# No_of_Earning_Members       False
# dtype: bool

# %% [markdown]
# #Mean Expenses of Household

# %%
Income_df['Mthly_HH_Expense'].mean() #Mean Expense of Household
# Out:
# 18818.0

# %%
Income_df['Mthly_HH_Expense'].median() #Median Expense of Household
# Out:
# 15500.0

# %% [markdown]
# #Monthly Maximum Expenses for most the Household

# %%
mth_exp_tmp=pd.crosstab(index=Income_df['Mthly_HH_Expense'],columns='count')
mth_exp_tmp.reset_index(inplace=True)
mth_exp_tmp[mth_exp_tmp['count']==Income_df.Mthly_HH_Expense.value_counts().max()]
# Out:
# col_0  Mthly_HH_Expense  count
# 18                25000      8

# %% [markdown]
# #Plot the Histogram to count the highest qualified memebers

# %%
Income_df['Highest_Qualified_Member'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Highest_Qualified_Member'>

# %% [markdown]
# # Calculating IQR(diffrence between 75% and 25% )

# %%
Income_df.plot(x='Mthly_HH_Income',y='Mthly_HH_Expense')
IQR=Income_df['Mthly_HH_Expense'].quantile(0.75)-Income_df['Mthly_HH_Expense'].quantile(0.25)
IQR
# Out:
# 15000.0

# %%
Income_df.plot(x='Mthly_HH_Income',y='Mthly_HH_Expense')
IQR=Income_df['Mthly_HH_Expense'].quantile(0.50)-Income_df['Mthly_HH_Expense'].quantile(0.25)
IQR
# Out:
# 5500.0

# %% [markdown]
# # Calculate standard Deviation first 4 Column

# %%
pd.DataFrame(Income_df.iloc[:,0:5].std().to_frame()).T # Calculate standard Deviation first 4 Column
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0     26097.908979      12090.216824           1.517382      6241.434948
#
#    Annual_HH_Income
# 0     320135.792123

# %% [markdown]
# # Calculate Variance for first 3 Column

# %%
pd.DataFrame(Income_df.iloc[:,0:4].var().to_frame()).T # Calculate Variance for first 3 Column
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt
# 0     6.811009e+08      1.461733e+08           2.302449     3.895551e+07

# %% [markdown]
# # Calculate the count of Highest qualified memebers

# %%
Income_df["Highest_Qualified_Member"].value_counts().to_frame().T # Calculate the count of Highest qualified memebers
# Out:
# Highest_Qualified_Member  Graduate  Under-Graduate  Professional  \
# count                           19              10            10
#
# Highest_Qualified_Member  Post-Graduate  Illiterate
# count                                 6           5

# %% [markdown]
# # Plot the Histogram to count the NO_of_Earning_Members

# %%
Income_df["No_of_Earning_Members"].value_counts().plot(kind='bar') # Plot the Histogram to count the NO_of_Earning_Members
# Out:
# <Axes: xlabel='No_of_Earning_Members'>

# %%
Income_df.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
sns.scatterplot(data=Income_df,x="Mthly_HH_Income",y="No_of_Fly_Members",hue="Emi_or_Rent_Amt",size="No_of_Earning_Members",palette="deep")
plt.title("Scatter plot:Mthly_HH_Income vs No_of_Fly_Members by Emi_or_Rent_Amt and Size")
plt.show()

# %%
sns.lineplot(data=Income_df,x="Mthly_HH_Income",y="Mthly_HH_Expense",hue="Highest_Qualified_Member",marker="o")
plt.title("Line plot:Total_bill by party Size and Sex")
plt.show()

# %%
sns.lineplot(data=Income_df,x="Mthly_HH_Income",y="Mthly_HH_Expense",hue="Highest_Qualified_Member",ci=95,marker="o")
plt.title("Line plot:Total_bill by party Size and Sex")
plt.show()
# Out:
# C:\Users\umari\AppData\Local\Temp\ipykernel_17124\4173534042.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.lineplot(data=Income_df,x="Mthly_HH_Income",y="Mthly_HH_Expense",hue="Highest_Qualified_Member",ci=95,marker="o")

# %%
sns.barplot(data=Income_df,x="No_of_Fly_Members",y="Mthly_HH_Expense",hue="Highest_Qualified_Member",palette="muted")
plt.title("Bar plot:Total_bill by No_of_Fly_Members and Mthly_HH_Expense")
plt.show()

# %%
sns.boxplot(data=Income_df,x="No_of_Fly_Members",y="Mthly_HH_Expense",hue="Highest_Qualified_Member",palette="Set2")
plt.title("Box plot:Tip by Day and Smoker Status")
plt.show()

# %%
Income_df["Highest_Qualified_Member"].value_counts().plot(kind='pie') # Plot the Histogram to count the NO_of_Fly_Members
# Out:
# <Axes: ylabel='count'>

# %%
Income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
Income_df["Emi_or_Rent_Amt"].value_counts().plot(kind='pie') # Plot the Histogram to count the NO_of_Fly_Members
# Out:
# <Axes: ylabel='count'>

# %%
Income_df["No_of_Earning_Members"].value_counts().plot(kind='pie') # Plot the Histogram to count the NO_of_Fly_Members
# Out:
# <Axes: ylabel='count'>

# %%
sns.lmplot(data=Income_df,x="Mthly_HH_Income",y="Mthly_HH_Expense",hue="Highest_Qualified_Member",palette="muted") # Plot the Histogram to count the NO_of_Fly_Members

# %%
sns.distplot(Income_df["Mthly_HH_Income"]) # Plot the Histogram to count the NO_of_Fly_Members
# Out:
# C:\Users\umari\AppData\Local\Temp\ipykernel_17124\603837302.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Income_df["Mthly_HH_Income"]) # Plot the Histogram to count the NO_of_Fly_Members
# <Axes: xlabel='Mthly_HH_Income', ylabel='Density'>

# %%
sns.displot(data=Income_df,x="Mthly_HH_Expense",hue="Highest_Qualified_Member",kde=True,palette="muted")

# %%
sns.histplot(data=Income_df,x="Mthly_HH_Expense",hue="No_of_Earning_Members",kde=True,palette="muted")
# Out:
# <Axes: xlabel='Mthly_HH_Expense', ylabel='Count'>

# %%
sns.violinplot(data=Income_df,x="Annual_HH_Income",y="Highest_Qualified_Member",hue="Highest_Qualified_Member",palette="Set2")
# Out:
# <Axes: xlabel='Annual_HH_Income', ylabel='Highest_Qualified_Member'>

# %%
sns.countplot(data=Income_df,x="Highest_Qualified_Member",hue="Emi_or_Rent_Amt",palette="Set1")
# Out:
# <Axes: xlabel='Highest_Qualified_Member', ylabel='count'>

# %%
sns.regplot(data=Income_df,x="Mthly_HH_Income",y="Mthly_HH_Expense",scatter_kws={"color":"blue"},line_kws={"color":"red"})
# Out:
# <Axes: xlabel='Mthly_HH_Income', ylabel='Mthly_HH_Expense'>

# %%
sns.pairplot(Income_df)

# %%
sns.stripplot(data=Income_df,x="Mthly_HH_Expense",y="Mthly_HH_Income",hue="Highest_Qualified_Member",palette="Set1")
# Out:
# <Axes: xlabel='Mthly_HH_Expense', ylabel='Mthly_HH_Income'>
