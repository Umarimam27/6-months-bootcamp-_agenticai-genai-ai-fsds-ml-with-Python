# %% [markdown]
# # Python Operators

# %% [markdown]
# #Arithematic Operator

# %%
x1,y1=10,5

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %%
3**2
# Out:
# 9

# %%
x2=2
y2=3
x2**y2
# Out:
# 8

# %% [markdown]
# #Assingment Operator

# %%
x=2

# %%
x=x+2 #if we want to add 2 to x then x=x+2

# %%
x
# Out:
# 4

# %%
x+=2 
x
# Out:
# 6

# %%
x+=2 
x
# Out:
# 8

# %%
x*=2
x
# Out:
# 16

# %%
x-=2
x
# Out:
# 14

# %%
x/=2
x
# Out:
# 7.0

# %%
x//=2
x
# Out:
# 3.0

# %% [markdown]
# #Unary Operator

# %%
n=7 #negattion
n
# Out:
# 7

# %%
m=-(n)
m
# Out:
# -7

# %%
n
# Out:
# 7

# %%
-n
# Out:
# -7

# %% [markdown]
# #Relational Operator

# %%
a=5
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
b=5

# %%
a==b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
a>b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# False

# %%
b=7

# %%
a!=b
# Out:
# True

# %% [markdown]
# #Logical Operator

# %%
a=5
b=4

# %%
a<8 and b<5 #refer to the table
# Out:
# True

# %%
a<8 and b<2
# Out:
# False

# %%
a>8 or b<2
# Out:
# False

# %%
x=False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
x=not x
x
# Out:
# True

# %%
x
# Out:
# True

# %%
not x
# Out:
# False

# %% [markdown]
# #Number System Conversion(bit-binary digit)

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
oct(25)
# Out:
# '0o31'

# %%
0o31
# Out:
# 25

# %%
int(0o31)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
0x19
# Out:
# 25

# %%
0x15
# Out:
# 21

# %% [markdown]
# # Swapping-2 Varibale in Python

# %% [markdown]
# (a,b=5,6) After Swap we Should get ==>(a,b=6,5)

# %%
a = 5
b = 6

# %%
a = b
b = a

# %%
print(a)
print(b)
# Out:
# 6
# 6

# %%
# in above secnerio we lost the value 5
a1 = 7
b1 = 8

# %%
temp = a1
a1 = b1
b1 = temp

# %%
print(a1)
print(b1)
# Out:
# 8
# 7

# %% [markdown]
# #Swapping Without Using 3rd Variable

# %%
a2=5
b2=6

# %%
#Swap variable formulas without using third variable
a2=a2+b2 # 5+6=11
b2=a2-b2 # 11-6=5
a2=a2-b2 # 11-5=6

# %%
print(a2) 
print(b2)
# Out:
# 6
# 5

# %%
a2,b2
# Out:
# (6, 5)

# %%
a2,b2=b2,a2 #how to work is b2 6 a2 is 5 first it goes into stack & then it reserve a2=6 & b2=5

# %%
print(a2)
print(b2)
# Out:
# 5
# 6

# %% [markdown]
# # ROT_TWO()
# Swaps the two top-most Stack items.
# Internally it uses the rotational Concept

# %% [markdown]
# # BITWISE OPERATOR

# %% [markdown]
# 1st Opertor--- Compliment Operator--> you will get this key below esc Character
# compliment means it always gives the neagitve value

# %%
~12
# Out:
# -13

# %%
~46
# Out:
# -47

# %%
~54
# Out:
# -55

# %%
~10
# Out:
# -11

# %% [markdown]
# #Bitwise and Operator

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
bin(13)
# Out:
# '0b1101'

# %%
print(bin(35))
print(bin(40))
# Out:
# 0b100011
# 0b101000

# %%
35 & 40 # 1101 & 1010
# Out:
# 32

# %%
35|40
# Out:
# 43
