# %% [markdown]
# # Statistics

# %% [markdown]
# #Stats for Machine Learning
# stats concept are link up to regression model--dv is continuous variable
# ,classification model-dependent variable is binary
#
# 1.Population v/s Sample
# 2.Descriptive Stats(
#     1. measures of central tendency
#     2.measures of assyemetry
#     3.measures of variability
#     4.measures of relationship
# )
# 3.inferential stats(
#         1.Probability
#         2.Distribution
#         3.Hypothesis testing(
#             Z test
#             T test
#             AB test
#         )
#         4.Hypotehsis null
#         5.Alternative hypothesis
#         6.type of errors.
# )
# 4.advance stats(
#     1.anove framework
#     2.r2
#     3.adjusted r2
#     4.mae(mean absolute error)
#     5.mse(mean squerd error)
#     6.rmse(root mean squared error)
# )
# 5.performance measure

# %% [markdown]
# #Population to sample---sampling technique
# sample to Population----inference technique
# random sample----all time the outcome comes different
#
# #Types Of Data
#
#   Categorical-Binary(Classification)                                        Numerical
# Categorical data represents groups                        |
# or categories                                  Discreate(Clustering)         Continuous
#                                          data is fixed          data keep inrcrease
#
# decriptive stats-mean,mode,min,max,sd
# 1-measure of central tendancy
#     mean,median,mode
# 2-measures of assymetry
#     skewness--where the data is located(left,right,centre)
#     1.+ve Skew--mean>median&mode(data stays at left & outlier at right)
#     2.-ve Skew--mode>median>meadn(data stays at right & outlier is at left)
#     3.0 Skew--mean=median=mode(data stays at centre & No Outlier)==normal distribution==gausian distribution==bell curve==0 Symmetry,int this out of three we have to consider bell curve.
#     kurtosis--
#     skewness graphs---flatten
#     kurtosis grapg----tailed
#
#     +ve skew= +ve kurtois==platry kurtic=<3
#     -ve skew= -ve kurtios==lapto curtic=>3
#     0 skew= normal distribution==meso curtic=3
#
# Library ==Scipy(stats,api)
